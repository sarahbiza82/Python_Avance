# %% [markdown]
# # Python Avancé

# %% [markdown]
# ## 1. GitHub

# %% [markdown]
# ### 1.1 Commandes
# - git clone url
# - git add nom_fichier ou git add . (pour tracker tout le dossier)
# - git commit -m "message"
# - git push
# - git pull
